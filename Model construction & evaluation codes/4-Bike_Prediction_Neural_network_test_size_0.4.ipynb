# %%
import numpy as np
import pandas as pd
data=pd.read_csv(r"C:\Users\neeraj bansal\Downloads\day.csv")
data.drop(['instant','dteday','temp','atemp','hum','windspeed','workingday','d_temp','casual','registered'],inplace=True,axis=1)
X=data[data.columns[:-2]]
y=data.iloc[:,-1]
from keras import Sequential
from keras.layers import Dense
import keras
def build_regressor():
    keras.backend.set_epsilon(1)
    regressor = Sequential()
    regressor.add(Dense(units=X_train.shape[1], input_dim=X_train.shape[1]))
    regressor.add(Dense(units=X_train.shape[1], input_dim=X_train.shape[1]))
    regressor.add(Dense(units=X_train.shape[1], input_dim=X_train.shape[1]))
    #regressor.add(Dense(units=8, input_dim=X_train.shape[1]))
    regressor.add(Dense(units=1))
    regressor.compile(optimizer='adam', loss='mean_absolute_percentage_error',  metrics=['mae','mape'])
    return regressor
from sklearn.preprocessing import  MinMaxScaler
sc= MinMaxScaler()
X= sc.fit_transform(X)
y= y.reshape(-1,1)
y=sc.fit_transform(y)
from sklearn.cross_validation import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4)
from keras.wrappers.scikit_learn import KerasRegressor
regressor = KerasRegressor(build_fn=build_regressor, batch_size=32,epochs=500)
from keras.callbacks import EarlyStopping  
earlystopper=EarlyStopping(monitor='mean_absolute_percentage_error',min_delta=0,patience=1,verbose=0,mode='auto')
results=regressor.fit(X_train,y_train)
y_pred= regressor.predict(X_test)
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.scatter(y_test, y_pred)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
from sklearn.metrics import r2_score
r2_score(y_test , y_pred)
# Out:
# C:\Users\neeraj bansal\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# C:\Users\neeraj bansal\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# Epoch 1/500
# 438/438 [==============================] - 0s 1ms/step - loss: 78.6068 - mean_absolute_error: 0.7861 - mean_absolute_percentage_error: 78.6068
# Epoch 2/500
# 438/438 [==============================] - 0s 127us/step - loss: 41.8338 - mean_absolute_error: 0.4183 - mean_absolute_percentage_error: 41.8338
# Epoch 3/500
# 438/438 [==============================] - 0s 89us/step - loss: 28.7280 - mean_absolute_error: 0.2873 - mean_absolute_percentage_error: 28.7280
# Epoch 4/500
# ...
